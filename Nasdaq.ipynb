# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json

# %%
path = '/Users/jibuthomas/Downloads/stock_market_data/nasdaq/json'
data = []
for files in os.listdir(path):
    with open(os.path.join(path, files)) as f:
        data.append(json.load(f))

# %%
len(data)
# Out:
# 2200

# %%
data[50]['chart']['result'][0]['timestamp'][0]
# Out:
# 1081949400

# %%
data_dict = {
    'stock': [],
    'day': [],
    'open': [],
    'high': [],
    'close': [],
    'low': [],
    'splits': [],
    'volume': [],
}

# %%
for i in data:
    try:
        data_dict['stock'].append(i['chart']['result'][0]['meta']['symbol'])
        data_dict['day'].append(i['chart']['result'][0]['timestamp'][0])
    except KeyError:
        data_dict['day'].append(np.nan)
    try:

# %%
data_dict['day']
# Out:
# [1528119000,
#  322151400,
#  nan,
#  783178200,
#  nan,
#  nan,
#  1056375000,
#  808407000,
#  783700200,
#  1340026200,
#  780759000,
#  1260973800,
#  nan,
#  nan,
#  1340026200,
#  1552055400,
#  1323268200,
#  1030541400,
#  1340026200,
#  nan,
#  nan,
#  526656600,
#  740755800,
#  430752600,
#  1058275800,
#  nan,
#  1177507800,
#  1123248600,
#  nan,
#  1166193000,
#  791044200,
#  99153000,
#  nan,
#  904051800,
#  1498138200,
#  nan,
#  802531800,
#  813591000,
#  nan,
#  nan,
#  nan,
#  1525354200,
#  1410528600,
#  1287149400,
#  709565400,
#  1248960600,
#  1370352600,
#  777130200,
#  nan,
#  1340026200,
#  1081949400,
#  1416407400,
#  867763800,
#  1143815400,
#  1386858600,
#  963927000,
#  nan,
#  nan,
#  704122200,
#  501345000,
#  nan,
#  415290600,
#  nan,
#  766675800,
#  nan,
#  622128600,
#  448813800,
#  955114200,
#  1340026200,
#  1354113000,
#  892733400,
#  1397223000,
#  339255000,
#  519485400,
#  1292509800,
#  1132237800,
#  783700200,
#  322151400,
# ...
